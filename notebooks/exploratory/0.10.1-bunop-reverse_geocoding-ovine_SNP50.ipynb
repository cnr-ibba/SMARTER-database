# %% [markdown]
# # Get Country from coordinates
# Try to get country informations relying on coordinates (Reverse Geocoding: for a reference, please see [here](https://towardsdatascience.com/reverse-geocoding-in-python-a915acf29eb6)

# %%
import pandas as pd
import pycountry

from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
from tqdm.notebook import tqdm

from src.features.smarterdb import global_connection, Dataset

# %%
global_connection()
dataset = Dataset.objects(file="ovine_SNP50HapMap_data.zip").get()
tqdm.pandas()

# %% [markdown]
# Open the kijas metadata files and display its contents:

# %%
with open(dataset.working_dir / "ovine_SNP50HapMap_data/kijas2012_dataset.xlsx", "rb") as handle:
    infos = pd.read_excel(handle)
infos.head()
# Out:
#                  Breed code   Latitude (N) degrees  Latitude (N) minutes  \
# 0        AfricanDorper   ADP                   -19                 -34.0
# 1   AfricanWhiteDorper   AWD                   -19                 -34.0
# 2              Afshari   AFS                    36                  40.0
# 3           Altamurana   ALT                    40                  49.0
# 4  AustralianCoopworth   CPW                    51                  17.0
#
#     latitude  Longitude (O) degrees  Longitude (O) minutes  longitude  \
# 0 -19.566667                     18                    7.0  18.116667
# 1 -19.566667                     18                    7.0  18.116667
# 2  36.666667                     48                   29.0  48.483333
# 3  40.816667                     16                   33.0  16.550000
# 4  51.283333                      0                   24.0   0.400000
#
#           Location/source                             Remark
# 0            Grootfontein  Recent Dorset-Black Persian cross
# 1            Grootfontein               Recent, hybrid breed
# 2  Maneshan, Zanjan, Iran                                NaN
# 3                Altamura                                NaN
# 4            West Malling                Derived from Romney

# %% [markdown]
# Define a new column in order to query for a location:

# %%
infos["coordinates"] = infos["latitude"].map(str) + "," + infos["longitude"].map(str)

# %%
locator = Nominatim(user_agent="myGeocoder", timeout=10)
rgeocode = RateLimiter(locator.reverse, min_delay_seconds=0.001)
def get_country(coordinate):
    data = rgeocode(coordinate, language="English")
    if data:
        country_code = data.raw['address']['country_code']
        return pycountry.countries.get(alpha_2=country_code).name
    else:
        return data
infos["country"] = infos["coordinates"].progress_apply(get_country)
# Out:
#   0%|          | 0/74 [00:00<?, ?it/s]

# %%
infos
# Out:
#                     Breed code   Latitude (N) degrees  Latitude (N) minutes  \
# 0           AfricanDorper   ADP                   -19                 -34.0
# 1      AfricanWhiteDorper   AWD                   -19                 -34.0
# 2                 Afshari   AFS                    36                  40.0
# 3              Altamurana   ALT                    40                  49.0
# 4     AustralianCoopworth   CPW                    51                  17.0
# ..                    ...   ...                   ...                   ...
# 69  SwissWhiteAlpineSheep   SWA                    46                  35.0
# 70                Tibetan   TIB                    32                   0.0
# 71   ValaisBlacknoseSheep   VBS                    46                  11.0
# 72         ValaisRedSheep   VRS                    46                  10.0
# 73              Wiltshire   WIL                    51                  15.0
#
#      latitude  Longitude (O) degrees  Longitude (O) minutes  longitude  \
# 0  -19.566667                     18                    7.0  18.116667
# 1  -19.566667                     18                    7.0  18.116667
# 2   36.666667                     48                   29.0  48.483333
# 3   40.816667                     16                   33.0  16.550000
# 4   51.283333                      0                   24.0   0.400000
# ..        ...                    ...                    ...        ...
# 69  46.583333                      8                   20.0   8.333333
# 70  32.000000                     84                    0.0  84.000000
# 71  46.183333                      7                   33.0   7.550000
# 72  46.166667                      7                   12.0   7.200000
# 73  51.250000                     -2                    0.0  -2.000000
#
#            Location/source                             Remark  \
# 0             Grootfontein  Recent Dorset-Black Persian cross
# 1             Grootfontein               Recent, hybrid breed
# 2   Maneshan, Zanjan, Iran                                NaN
# 3                 Altamura                                NaN
# 4             West Malling                Derived from Romney
# ..                     ...                                ...
# 69              Swiss Alps                                NaN
# 70                   Tibet                                NaN
# 71                  Valais                                NaN
# 72             West Valais                                NaN
# 73               Wiltshire                                NaN
#
#                            coordinates                    country
# 0   -19.5666666666667,18.1166666666667                    Namibia
# 1   -19.5666666666667,18.1166666666667                    Namibia
# 2    36.6666666666667,48.4833333333333  Iran, Islamic Republic of
# 3               40.8166666666667,16.55                      Italy
# 4                 51.2833333333333,0.4             United Kingdom
# ..                                 ...                        ...
# 69   46.5833333333333,8.33333333333333                Switzerland
# 70                           32.0,84.0                      China
# 71               46.1833333333333,7.55                Switzerland
# 72                46.1666666666667,7.2                Switzerland
# 73                          51.25,-2.0             United Kingdom
#
# [74 rows x 12 columns]

# %%
infos.to_excel(dataset.working_dir / "ovine_SNP50HapMap_data/kijas2012_dataset_fix.xlsx", index=False)

# %% [markdown]
# The only location I couldn't resolve is "Dorset, UK", which has wrong coordinates. I resolve the location and fix those coordinates in excel table

# %%
dorset = locator.geocode("Dorset, UK")
dorset.latitude, dorset.longitude
# Out:
# (50.79683685, -2.34473226124306)

# %% [markdown]
# Next I will put the updated `xlsx` file in the row dataset
